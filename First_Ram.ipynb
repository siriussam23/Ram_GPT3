# %%
import pandas as pd
import nltk
import spacy
import docx2txt
from xlrd import open_workbook
import tensorflow as tf
import textract
from transformers import pipeline
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import GPT2Model, GPT2Config, GPT2Tokenizer, GPT2TokenizerFast
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
#tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

# %%
class pfi(object):
    def __init__(self, Title, Taxon):
        self.Title = Title
        self.Taxon = Taxon


    def __str__(self):
        return("pfi object:\n"
               "  Title = {0}\n"
               " Taxon = {1}"

               .format(self.Title,self.Taxon))


tokenizer("Hello world")['input_ids']
tokenizer("Hello world")['input_ids']

#ignore the Tokenizer.. thank you

# Initializing a GPT2 configuration
configuration = GPT2Config()

# %%
text1 = docx2txt.process("/Users/scrysam/Movies/Santosh_P/iSpatialTec/Ram/Data_Standards_Compliance_and_Maturity_Dashboard_application_enhancements/Cognitive_Digital_Assistant.docx")
print (text1)
# Out:
# ADDA  - Cognitive Data Expert
#
# Statement of Work (SOW)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Author: Simon O’Doherty
#
# Date: 25th August 2019
#
# Document History
#
#
#
# Revision History
#
# Date of this revision:
#
# Date of next revision:
#
#
#
# Revision Number
#
# Revision Date
#
# Summary of changes
#
#
#
#
#
#
#
#
#
#
#
# Approvals
#
# This document requires the following approvals.
#
#
#
# Name
#
# Title
#
#
#
#
#
#
#
# Distribution
#
# This document has been distributed to:
#
#
#
# Name
#
# Title
#
#
#
#
#
#
#
#
#
#
# Contents
#
# 	Document History	2
#
# 	Revision History	2
#
# 	Approvals	2
#
# 	Distribution	2
#
# 	Contents	3
#
# 	Introduction	4
#
# 	Description	4
#
# 	Use Case Descriptions and Business Requirements	4
#
# 	Business Goals	4
#
# 	User Scenario (Current State)	4
#
# 	Steps	5
#
# 	User Scenario (Future State)	5
#
# 	Steps	5
#
# ...

# %%
text2 = docx2txt.process("/Users/scrysam/Movies/Santosh_P/iSpatialTec/Ram/Data_Standards_Compliance_and_Maturity_Dashboard_application_enhancements/ADDA-DMP-Data-Catalog-Implementation-Guidelines.docx")
print (text2)
# Out:
# Data Catalog Implementation Guidelines
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Overview
#
# The implementation guidelines were developed based on the controls governing the implementation of the 11 data management domains:
#
#
#
# This document describes more specifically the data catalog implementation guidelines, the processes that enable data cataloguing and the roles and responsibilities that enable its development and maintenance.
#
# The data catalog shall serve as a repository to collect information about an ADGE’s data in a single location where this information can be accessed and maintained more conveniently. Furthermore, though some data may be relatively well understood, it is unlikely that even this data is described as comprehensively as it should be.
#
# The data catalog consists of three artifacts:
#
# Dataset Inventory: document that incorporates a full list of the ADGE’s data
#
# ...

# %%
sub = text2[0:1000]
print (sub)
#This proves that it is a string
# Out:
# Data Catalog Implementation Guidelines
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Overview
#
# The implementation guidelines were developed based on the controls governing the implementation of the 11 data management domains:
#
#
#
# This document describes more specifically the data catalog implementation guidelines, the processes that enable data cataloguing and the roles and responsibilities that enable its development and maintenance.
#
# The data catalog shall serve as a repository to collect information about an ADGE’s data in a single location where this information can be accessed and maintained more conveniently. Furthermore, though some data may be relatively well understood, it is unlikely that even this data is described as comprehensively as it should be.
#
# The data catalog consists of three artifacts:
#
# Dataset Inventory: document that incorporates a full list of the ADGE’s data
#
# ...

# %%
text3 = docx2txt.process("/Users/scrysam/Movies/Santosh_P/iSpatialTec/Ram/Data_Standards_Compliance_and_Maturity_Dashboard_application_enhancements/ADDA-DMP-Data-Sharing-Implementation-Guidelines-03032020-vfinal.docx")
print (text3)
# Out:
# Data Sharing Implementation Guidelines
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Overview
#
#
#
# The implementation guidelines were developed based on the controls governing the implementation of the 11 data management domains:
#
#
#
# This document describes more specifically the data sharing implementation guidelines, the different processes that govern data sharing and the roles and responsibilities that enable them.
#
# There are two types of data exchange. The first type is based on transactional data which is exchanged between ADGEs to enable the fulfillment of a government service provided by an ADGE. The second type is based on a specific data need raised by an ADGE to another ADGE to enable a data-dependent initiative (e.g. analytics). To differentiate between these two types of exchanges throughout this document, the first type will be referred to as “data exchange”, while the second will be referred to as “data sharing”.
#
# ...

# %%
text4 = docx2txt.process("/Users/scrysam/Movies/Santosh_P/iSpatialTec/Ram/Data_Standards_Compliance_and_Maturity_Dashboard_application_enhancements/ADDA-DMP-Open-Data-Implementation-Guidelines-05032020-vfinal.docx")
print (text4)
# Out:
# Open Data Implementation Guidelines
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Overview
#
#
#
# The implementation guidelines were developed based on the controls governing the implementation of the 11 data management domains:
#
#
#
# This document describes more specifically the open data implementation guidelines, the different processes that govern open data and the roles and responsibilities that enable them. We will be looking at three processes that compose the open data value chain:
#
# Open Data Review
#
# Open Data Publishing
#
# Open Data Maintenance
#
# External users of the ADGE's data that are not affiliated with the Abu Dhabi Government or its contracted suppliers shall be bound by usage licenses developed by the ADGE. Such usage licenses shall align with the ADGE's Open Data standards (refer to Open Data Standards and Policies for details).
#
#
#
#
#
#
#
#
#
#
#
# Open Data Review
#
# Overview
#
# ...

# %%
text = text1+text2+text3+text4
print (text)
# Out:
# ADDA  - Cognitive Data Expert
#
# Statement of Work (SOW)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Author: Simon O’Doherty
#
# Date: 25th August 2019
#
# Document History
#
#
#
# Revision History
#
# Date of this revision:
#
# Date of next revision:
#
#
#
# Revision Number
#
# Revision Date
#
# Summary of changes
#
#
#
#
#
#
#
#
#
#
#
# Approvals
#
# This document requires the following approvals.
#
#
#
# Name
#
# Title
#
#
#
#
#
#
#
# Distribution
#
# This document has been distributed to:
#
#
#
# Name
#
# Title
#
#
#
#
#
#
#
#
#
#
# Contents
#
# 	Document History	2
#
# 	Revision History	2
#
# 	Approvals	2
#
# 	Distribution	2
#
# 	Contents	3
#
# 	Introduction	4
#
# 	Description	4
#
# 	Use Case Descriptions and Business Requirements	4
#
# 	Business Goals	4
#
# 	User Scenario (Current State)	4
#
# 	Steps	5
#
# 	User Scenario (Future State)	5
#
# 	Steps	5
#
# ...
